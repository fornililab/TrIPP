# %%
from pkai.pKAI import pKAI

# %%
pka_result = pKAI(pdb='/home/ivan/Sarcomere/Lysozyme/TrIPP_test/TrIPP/tutorial/tmp.pdb', model_name='pKAI',device='cpu')
# Out:
# A         1 LYS  11.09
# A         6 CYS  10.23
# A         7 GLU   2.73
# A        13 LYS  11.41
# A        15 HIS   6.39
# A        18 ASP   2.62
# A        20 TYR   9.90
# A        23 TYR  10.30
# A        30 CYS  12.28
# A        33 LYS  10.28
# A        35 GLU   2.72
# A        48 ASP   2.29
# A        52 ASP   2.54
# A        53 TYR   9.83
# A        64 CYS  12.73
# A        66 ASP   1.42
# A        76 CYS  12.98
# A        80 CYS  13.18
# A        87 ASP   2.73
# A        94 CYS  13.99
# A        96 LYS  11.05
# A        97 LYS  11.03
# A       101 ASP   2.69
# A       115 CYS  13.57
# A       116 LYS   9.98
# A       119 ASP   2.10
# A       127 CYS  10.75

# %%
pka_result
# Out:
# [('A', 1, 'LYS', 11.09),
#  ('A', 6, 'CYS', 10.23),
#  ('A', 7, 'GLU', 2.73),
#  ('A', 13, 'LYS', 11.41),
#  ('A', 15, 'HIS', 6.39),
#  ('A', 18, 'ASP', 2.62),
#  ('A', 20, 'TYR', 9.9),
#  ('A', 23, 'TYR', 10.3),
#  ('A', 30, 'CYS', 12.28),
#  ('A', 33, 'LYS', 10.28),
#  ('A', 35, 'GLU', 2.72),
#  ('A', 48, 'ASP', 2.29),
#  ('A', 52, 'ASP', 2.54),
#  ('A', 53, 'TYR', 9.83),
#  ('A', 64, 'CYS', 12.73),
#  ('A', 66, 'ASP', 1.42),
#  ('A', 76, 'CYS', 12.98),
#  ('A', 80, 'CYS', 13.18),
#  ('A', 87, 'ASP', 2.73),
#  ('A', 94, 'CYS', 13.99),
#  ('A', 96, 'LYS', 11.05),
#  ('A', 97, 'LYS', 11.03),
#  ('A', 101, 'ASP', 2.69),
#  ('A', 115, 'CYS', 13.57),
#  ('A', 116, 'LYS', 9.98),
#  ('A', 119, 'ASP', 2.1),
#  ('A', 127, 'CYS', 10.75)]
