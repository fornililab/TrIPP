# %%
from tripp.Clustering import Clustering
import pandas as pd
import numpy as np
import os
import pytest
import glob

def get_data_path(filename):
    return os.path.join(os.path.dirname('/Users/kafuman/Ivan/TrIPP/TrIPP/tests/'), "data", filename)
def check_dir(path):
    if not os.path.isdir(path):
        # Make directory if not present
        os.makedirs(path) 
    else:
        # Remove files named .temp* in the directory before proceeding.
        [os.remove(file) for file in glob.glob(f'{path}/*')]
    return path

# %%
Clust = Clustering(topology_file=get_data_path('lyso.pdb'),
                           trajectory_file={'MD1': get_data_path('lyso_test.xtc')},
                           pka_file=get_data_path('lyso_test_pkai_pka.csv'),
                           selections=['chainID A and resid 35', 'chainID A and resid 52'],
                           output_directory=check_dir('test_output/TestClustering/TestPKAIClusteringMatrix'),
                           output_prefix='lyso_test_clustering',
                           buriedness_file=get_data_path('lyso_test_propka_buriedness.csv'),
                            include_distances=False,
                            include_buriedness=True,
                            dimensionality_reduction=False)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 Clust = Clustering(topology_file=get_data_path('lyso.pdb'),
#       2                            trajectory_file={'MD1': get_data_path('lyso_test.xtc')},
#       3                            pka_file=get_data_path('lyso_test_pkai_pka.csv'),
#       4                            selections=['chainID A and resid 35', 'chainID A and resid 52'],
#       5                            output_directory=check_dir('test_output/TestClustering/TestPKAIClusteringMatrix'),
#       6                            output_prefix='lyso_test_clustering',
#       7                            buriedness_file=get_data_path('lyso_test_propka_buriedness.csv'),
#       8                             include_distances=False,
#       9                             include_buriedness=True,
#      10                             dimensionality_reduction=False)
#
# File ~/Ivan/TrIPP/TrIPP/tripp/Clustering.py:142, in Clustering.__init__(self, topology_file, trajectory_file, pka_file, selections, output_directory, output_prefix, buriedness_file, include_distances, include_buriedness, dimensionality_reduction)
#     138         df = None
#     140     return df
# --> 142 self.pka_df = make_pka_or_buriedness_df(pka_file)
#     143 self.buriedness_df = make_pka_or_buriedness_df(buriedness_file)
#     145 (
#     146     self.clustering_matrix,
#     147     self.times,
#    (...)
#     158     self.include_buriedness,
#     159 )
#
# File ~/Ivan/TrIPP/TrIPP/tripp/Clustering.py:126, in Clustering.__init__.<locals>.make_pka_or_buriedness_df(file)
#     124 def make_pka_or_buriedness_df(file):
#     125     if isinstance(file, str):
# --> 126         df = pd.read_csv(file, index_col="Time [ps]")
#     127         df["Trajectories"] = "Unnamed trajectory"
#     129     elif isinstance(file, list):
#
# File ~/Library/Caches/pypoetry/virtualenvs/tripp-3swtsHu9-py3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tripp-3swtsHu9-py3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:577, in _read(filepath_or_buffer, kwds)
#     574 _validate_names(kwds.get("names", None))
#     576 # Create the parser.
# --> 577 parser = TextFileReader(filepath_or_buffer, **kwds)
#     579 if chunksize or iterator:
#     580     return parser
#
# File ~/Library/Caches/pypoetry/virtualenvs/tripp-3swtsHu9-py3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1407, in TextFileReader.__init__(self, f, engine, **kwds)
#    1404     self.options["has_index_names"] = kwds["has_index_names"]
#    1406 self.handles: IOHandles | None = None
# -> 1407 self._engine = self._make_engine(f, self.engine)
#
# File ~/Library/Caches/pypoetry/virtualenvs/tripp-3swtsHu9-py3.9/lib/python3.9/site-packages/pandas/io/parsers/readers.py:1661, in TextFileReader._make_engine(self, f, engine)
#    1659     if "b" not in mode:
#    1660         mode += "b"
# -> 1661 self.handles = get_handle(
#    1662     f,
#    1663     mode,
#    1664     encoding=self.options.get("encoding", None),
#    1665     compression=self.options.get("compression", None),
#    1666     memory_map=self.options.get("memory_map", False),
#    1667     is_text=is_text,
#    1668     errors=self.options.get("encoding_errors", "strict"),
#    1669     storage_options=self.options.get("storage_options", None),
#    1670 )
#    1671 assert self.handles is not None
#    1672 f = self.handles.handle
#
# File ~/Library/Caches/pypoetry/virtualenvs/tripp-3swtsHu9-py3.9/lib/python3.9/site-packages/pandas/io/common.py:859, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     854 elif isinstance(handle, str):
#     855     # Check whether the filename is to be opened in binary mode.
#     856     # Binary mode does not support 'encoding' and 'newline'.
#     857     if ioargs.encoding and "b" not in ioargs.mode:
#     858         # Encoding
# --> 859         handle = open(
#     860             handle,
#     861             ioargs.mode,
#     862             encoding=ioargs.encoding,
#     863             errors=errors,
#     864             newline="",
#     865         )
#     866     else:
#     867         # Binary mode
#     868         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/Users/kafuman/Ivan/TrIPP/TrIPP/data/lyso_test_pkai_pka.csv'
